# %%
import openai

# %%
#upload openai api key
OPENAI_API_KEY = "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"

# %%
#load and open the openai key
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %%
#input and upload file
#audio_file = open("/content/sample-1.mp3", 'rb')
prompt = "The way he plays with that, you know, there are some people who say it's on creme de benso, instead of court in a musical, I'll just not tell you which one, because I'm just telling you, try it, that's the..."

# %%
#audio synthesizing (Text-to-Speech)
output = client.audio.speech.create(model='tts-1', voice='alloy', input=prompt)

# %%
output.stream_to_file("speech.mp3")
print("Audio saved to speech.mp3")
# Out:
# Audio saved to speech.mp3
# /tmp/ipykernel_1936/3360743382.py:1: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   output.stream_to_file("speech.mp3")

# %%
from IPython.display import Audio

Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
